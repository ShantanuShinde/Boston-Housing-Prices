# %%
import pandas as pd

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
housing = pd.read_csv('../input/boston-house-prices/housing.csv', header=None, delimiter=r"\s+", names=column_names)

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
import pandas_profiling as pp
pp.ProfileReport(housing)
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
import plotly
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode,iplot 
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
col1 = "CRIM"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values, x=v1.index, name="Crime Rate")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Crime Rate vs Median House Price",'yaxis':{'title':"Crime Rate"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="2fe82d66-adfb-4ca1-81e2-62294c3952d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fe82d66-adfb-4ca1-81e2-62294c3952d3")) {
#                     Plotly.newPlot(
#                         '2fe82d66-adfb-4ca1-81e2-62294c3952d3',
# ...

# %%
col1 = "ZN"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values, x=v1.index, name="Residential Land")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Residential Land vs Median House Price",'yaxis':{'title':"Residential Land"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="81bcca34-ae1e-47c1-90b8-e4a98907ee0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("81bcca34-ae1e-47c1-90b8-e4a98907ee0b")) {
#                     Plotly.newPlot(
#                         '81bcca34-ae1e-47c1-90b8-e4a98907ee0b',
# ...

# %%
col1 = "INDUS"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values, x=v1.index, name="Non-retail business")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Non-retail business vs Median House Price",'yaxis':{'title':"Non-retail business"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="64e88288-935a-4af3-bd41-5b8c711af7ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("64e88288-935a-4af3-bd41-5b8c711af7ac")) {
#                     Plotly.newPlot(
#                         '64e88288-935a-4af3-bd41-5b8c711af7ac',
# ...

# %%
col1 = "CHAS"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values*50, x=v1.index, name="Town Bounds Charles River")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Town Bounds Charles River vs Median House Price",'yaxis':{'title':"Town Bounds Charles River"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="166ac5e1-c01f-46b0-9184-297cb4569441" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("166ac5e1-c01f-46b0-9184-297cb4569441")) {
#                     Plotly.newPlot(
#                         '166ac5e1-c01f-46b0-9184-297cb4569441',
# ...

# %%
col1 = "NOX"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values*50, x=v1.index, name="Nitric oxide Concentration")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Nitric Oxide Concentration vs Median House Price",'yaxis':{'title':"Nitric Oxide Concentration"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="8e89e2be-8eb5-4168-a0a5-521c4a405dd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e89e2be-8eb5-4168-a0a5-521c4a405dd0")) {
#                     Plotly.newPlot(
#                         '8e89e2be-8eb5-4168-a0a5-521c4a405dd0',
# ...

# %%
col1 = "RM"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values*10, x=v1.index, name="No. of average rooms")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"No. of average rooms vs Median House Price",'yaxis':{'title':"No of average rooms"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="aa45e874-a248-44e7-a657-cad63eeecd73" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa45e874-a248-44e7-a657-cad63eeecd73")) {
#                     Plotly.newPlot(
#                         'aa45e874-a248-44e7-a657-cad63eeecd73',
# ...

# %%
col1 = "AGE"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values, x=v1.index, name="Age of owner")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Age of owner vs Median House Price",'yaxis':{'title':"Age of owner"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="43d570e8-5093-4338-8856-25273e376140" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43d570e8-5093-4338-8856-25273e376140")) {
#                     Plotly.newPlot(
#                         '43d570e8-5093-4338-8856-25273e376140',
# ...

# %%
col1 = "DIS"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values*10, x=v1.index, name="Distance from employment center")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Distance from employment center vs Median House Price",'yaxis':{'title':"Distance from employment center"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="1fdc6539-0a44-4d54-aeec-fde419adc717" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1fdc6539-0a44-4d54-aeec-fde419adc717")) {
#                     Plotly.newPlot(
#                         '1fdc6539-0a44-4d54-aeec-fde419adc717',
# ...

# %%
col1 = "RAD"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values*10, x=v1.index, name="Accessibility to Highway")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Accessibility to Highway vs Median House Price",'yaxis':{'title':"Accessibility to Highway"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="127ccc2a-dcb2-4a01-b31d-8a24c1a2a160" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("127ccc2a-dcb2-4a01-b31d-8a24c1a2a160")) {
#                     Plotly.newPlot(
#                         '127ccc2a-dcb2-4a01-b31d-8a24c1a2a160',
# ...

# %%
col1 = "TAX"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values, x=v1.index, name="Tax rate")
scat2 = go.Scatter(y=v2.values*10, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Tax rate vs Median House Price",'yaxis':{'title':"Tax rate"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="dfffdffd-0d40-4ad1-b445-bede496f6870" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dfffdffd-0d40-4ad1-b445-bede496f6870")) {
#                     Plotly.newPlot(
#                         'dfffdffd-0d40-4ad1-b445-bede496f6870',
# ...

# %%
col1 = "PTRATIO"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values, x=v1.index, name="Pupil to teacher ratio")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Pupil to teacher ratio vs Median House Price",'yaxis':{'title':"Pupil to teacher ratio"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="a7107c36-9aae-4740-ac46-766d71262c31" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7107c36-9aae-4740-ac46-766d71262c31")) {
#                     Plotly.newPlot(
#                         'a7107c36-9aae-4740-ac46-766d71262c31',
# ...

# %%
col1 = "B"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values, x=v1.index, name="Proportion of black population")
scat2 = go.Scatter(y=v2.values*10, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"Proportion of black population vs Median House Price",'yaxis':{'title':"Proportion of black population"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="9ff81d8e-5369-4e11-b720-db22a45fb8a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9ff81d8e-5369-4e11-b720-db22a45fb8a4")) {
#                     Plotly.newPlot(
#                         '9ff81d8e-5369-4e11-b720-db22a45fb8a4',
# ...

# %%
col1 = "LSTAT"
col2 = "MEDV"
v1 = housing[col1]
v2 = housing[col2]

scat1 = go.Scatter(y = v1.values, x=v1.index, name="% Lower status of population")
scat2 = go.Scatter(y=v2.values, x=v2.index, name="Median Value")

data = [scat1, scat2]

layout={'title':"% Lower status of population vs Median House Price",'yaxis':{'title':"% Lower status of population"},'xaxis':{'title':'Towns'}}
fig = go.Figure(data=data, layout=layout)
fig.layout.template = "presentation"

iplot(fig)
# Out:
# <div>
#
#
#             <div id="0c1e4bfe-29b1-497d-a483-c60059e450e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0c1e4bfe-29b1-497d-a483-c60059e450e7")) {
#                     Plotly.newPlot(
#                         '0c1e4bfe-29b1-497d-a483-c60059e450e7',
# ...

# %%
housing.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
fig,ax = plt.subplots(figsize=(9,8))
ax = sb.heatmap(housing.corr(), annot=True,linewidths=.5,fmt='.1f')
plt.show()

# %%
X = housing.drop(["MEDV"],axis=1)
Y = housing["MEDV"].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lars
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoLars
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score

# %%
#linear regression
lr = LinearRegression(n_jobs=3)
lr.fit(X_train,Y_train)
#ridge
r = Ridge(alpha=0.3)
r.fit(X_train,Y_train)
#sgd regression
sgd_r = SGDRegressor(alpha=0.3)
sgd_r.fit(X_train,Y_train)
#elastic net
eln = ElasticNet(alpha=0.3)
eln.fit(X_train, Y_train)
#lars
lrs = Lars()
lrs.fit(X_train, Y_train)
#lasso
ls = Lasso(alpha=0.3)
ls.fit(X_train, Y_train)
#lasso lars
lslrs = LassoLars(alpha=0.3)
lslrs.fit(X_train, Y_train)
# Out:
# LassoLars(alpha=0.3, copy_X=True, eps=2.220446049250313e-16, fit_intercept=True,
#           fit_path=True, max_iter=500, normalize=True, positive=False,
#           precompute='auto', verbose=False)

# %%
models = {"Linear Regression":lr,"Ridge":r,"SGD Regressor":sgd_r,"Elastic Net":eln,"Lars":lrs,"Lasso":ls,"LassoLars":lslrs}
train_mse = {}
val_mse = {}
for i,model in enumerate(models):
    print("Model: {}\n".format(model))
    
    pred = models[model].predict(X_train)
    print("Training Scores:")
    train_mse[model] = mean_squared_error(Y_train,pred)
    print("Mean Sqaured Error: {}".format(train_mse[model]))
    print("Mean Absolute Error: {}".format(mean_absolute_error(Y_train,pred)))
    print("Explained Variance Score: {}".format(explained_variance_score(Y_train,pred)))
    print("R2 Score: {}\n".format(r2_score(Y_train,pred)))
    
    
    pred = models[model].predict(X_test)
    print("Validation Scores:")
    val_mse[model] = mean_squared_error(Y_test,pred)
    print("Mean Sqaured Error: {}".format(val_mse[model]))
    print("Mean Absolute Error: {}".format(mean_absolute_error(Y_test,pred)))
    print("Explained Variance Score: {}".format(explained_variance_score(Y_test,pred)))
    print("R2 Score: {}\n\n".format(r2_score(Y_test,pred)))
# Out:
# Model: Linear Regression
#
# Training Scores:
# Mean Sqaured Error: 19.93655988564412
# Mean Absolute Error: 3.1582556799905714
# Explained Variance Score: 0.7629262953567935
# R2 Score: 0.7629262953567935
#
# Validation Scores:
# Mean Sqaured Error: 41.72457625585766
# Mean Absolute Error: 3.935792084119314
# Explained Variance Score: 0.5149668365824072
# R2 Score: 0.5149662051867065
#
#
# Model: Ridge
#
# Training Scores:
# Mean Sqaured Error: 19.962232568860966
# Mean Absolute Error: 3.156248292849477
# Explained Variance Score: 0.7626210110874281
# R2 Score: 0.7626210110874281
#
# Validation Scores:
# Mean Sqaured Error: 42.11629202351477
# Mean Absolute Error: 3.9227631715522344
# Explained Variance Score: 0.5104143760800941
# R2 Score: 0.5104126446158366
#
#
# Model: SGD Regressor
#
# Training Scores:
# Mean Sqaured Error: 1.8489153819357255e+28
# Mean Absolute Error: 129117755352229.06
# Explained Variance Score: -2.1615709021890265e+25
# R2 Score: -2.198620131464821e+26
#
# ...

# %%
model_train_error = pd.Series(data=list(train_mse.values()),index=list(train_mse.keys()))
model_val_error = pd.Series(data=list(val_mse.values()),index=list(val_mse.keys())

# %% [markdown]
# SGD Regressor is outlier, so need to remove it

# %%
model_train_error=model_train_error.drop(["SGD Regressor"])
model_val_error=model_val_error.drop(["SGD Regressor"])

# %%
fig= plt.figure(figsize=(10,6))
model_train_error.sort_values().plot.barh()
plt.show()

# %%
fig= plt.figure(figsize=(10,6))
model_val_error.sort_values().plot.barh()
plt.show()

# %% [markdown]
# # **Conclusion**
# Lars model performs the best
